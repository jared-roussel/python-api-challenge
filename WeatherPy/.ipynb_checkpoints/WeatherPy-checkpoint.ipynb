# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Import dependences
import pandas as pd
import json
import matplotlib.pyplot as plt
import random
from citipy import citipy
import numpy as np
import requests
import time
import sys
from pprint import pprint
from scipy.stats import linregress
#!pip install sklearn
from sklearn import datasets
#from config import weather_api_key
weather_api_key = '877069c5920cb3ad3f4efa6dac5c6f9e'

# %% [markdown]
# ## Generate Cities List

# %%
#Step1: Need random latitude and longitude values to feed to citipy

#Create lists and add random latitude and longitude values
np.random.seed(672812)
long_list = [random_long for random_long in np.random.randint(-180,180,1500)]
# print(len(long_list))
lat_list = [random_lat for random_lat in np.random.randint(-90,90,1500)]
# print(len(lat_list))

#Feed random latitude and longitude values to citipy
cities = []
index_max = len(lat_list)
#index_max
for index in range(0,index_max):
    lat_value = lat_list[index]
    #print(lat_value)
    long_value = long_list[index]
    #print(long_value)
    city = citipy.nearest_city(lat_value,long_value)
    city_name = city.city_name
    
    if city_name not in cities:
        cities.append(city_name)
# print(cities, '\n', len(cities))

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Define the base URL
base_url = "https://api.openweathermap.org/data/2.5/weather?q="

# %%
#Set empty lists for appending the results to
lat_list_api = []
long_list_api = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
country_list = []
date_list = []
found_cities = []
all_cities_data = []

#Loop through the cities previously found from citipy
for city_index in range(0, len(cities)):
    city_name = cities[city_index]
    print(f'Processing city # {city_index} | City name = {city_name}.')
    print('-----------------------------------------------------------------')
    
    try: 
        #API request
        query_url = f'{base_url}{city_name}&appid={weather_api_key}'
        response = requests.get(query_url).json()
        
        #Parse response
        lat = response['coord']['lat']
        long = response['coord']['lon']
        max_temp = response['main']['temp_max']
        humidity = response['main']['humidity']
        cloudiness = response['clouds']['all']
        wind_speed = response['wind']['speed']
        country = response['sys']['country']
        date = response['dt']
     
        #Append to lists
        date_list.append(date)
        lat_list_api.append(lat)
        long_list_api.append(long)
        country_list.append(country)
        max_temp_list.append(max_temp)
        humidity_list.append(humidity)
        wind_speed_list.append(wind_speed)
        cloudiness_list.append(cloudiness)
        found_cities.append(city_name)   
       
        #Append to dictionary
        all_cities_data.append({"City": city_name,
                        "Lat": lat,
                        "Long": long,
                        "Max Temp": max_temp,
                        "Humidity": humidity,
                        "Cloudiness": cloudiness,
                        "Wind Speed": wind_speed,
                        "Country": country,
                        "Date": date})
    
    except :
        #if exception in the API request
        print(f'City {city_name} is not found.')
        #print(sys.exc_info()[0])
        print('-----------------------------------------------------------------') 
    time.sleep(1)
# Out:
# Processing city # 0 | City name = cidreira.
# -----------------------------------------------------------------
# Processing city # 1 | City name = hermanus.
# -----------------------------------------------------------------
# Processing city # 2 | City name = rikitea.
# -----------------------------------------------------------------
# Processing city # 3 | City name = harper.
# -----------------------------------------------------------------
# Processing city # 4 | City name = oksfjord.
# -----------------------------------------------------------------
# Processing city # 5 | City name = margate.
# -----------------------------------------------------------------
# Processing city # 6 | City name = barvinkove.
# -----------------------------------------------------------------
# Processing city # 7 | City name = severo-kurilsk.
# -----------------------------------------------------------------
# Processing city # 8 | City name = arraial do cabo.
# -----------------------------------------------------------------
# Processing city # 9 | City name = cape town.
# -----------------------------------------------------------------
# Processing city # 10 | City name = punta arenas.
# -----------------------------------------------------------------
# Processing city # 11 | City name = carnarvon.
# -----------------------------------------------------------------
# Processing city # 12 | City name = cherskiy.
# -----------------------------------------------------------------
# Processing city # 13 | City name = tieli.
# -----------------------------------------------------------------
# Processing city # 14 | City name = tiksi.
# -----------------------------------------------------------------
# Processing city # 15 | City name = chuy.
# -----------------------------------------------------------------
# Processing city # 16 | City name = mataura.
# -----------------------------------------------------------------
# Processing city # 17 | City name = qaanaaq.
# -----------------------------------------------------------------
# Processing city # 18 | City name = grenada.
# -----------------------------------------------------------------
# Processing city # 19 | City name = pangnirtung.
# -----------------------------------------------------------------
# Processing city # 20 | City name = lavrentiya.
# -----------------------------------------------------------------
# Processing city # 21 | City name = narsaq.
# -----------------------------------------------------------------
# Processing city # 22 | City name = hilo.
# -----------------------------------------------------------------
# Processing city # 23 | City name = katsuura.
# -----------------------------------------------------------------
# Processing city # 24 | City name = sao joao da barra.
# -----------------------------------------------------------------
# Processing city # 25 | City name = busselton.
# -----------------------------------------------------------------
# Processing city # 26 | City name = mar del plata.
# -----------------------------------------------------------------
# Processing city # 27 | City name = turmalina.
# -----------------------------------------------------------------
# Processing city # 28 | City name = gambiran.
# -----------------------------------------------------------------
# Processing city # 29 | City name = quang ngai.
# -----------------------------------------------------------------
# Processing city # 30 | City name = sao filipe.
# -----------------------------------------------------------------
# Processing city # 31 | City name = hobart.
# -----------------------------------------------------------------
# Processing city # 32 | City name = khoy.
# -----------------------------------------------------------------
# Processing city # 33 | City name = bredasdorp.
# -----------------------------------------------------------------
# Processing city # 34 | City name = victoria.
# -----------------------------------------------------------------
# Processing city # 35 | City name = albany.
# -----------------------------------------------------------------
# Processing city # 36 | City name = puerto ayora.
# -----------------------------------------------------------------
# Processing city # 37 | City name = barrow.
# -----------------------------------------------------------------
# Processing city # 38 | City name = cremona.
# -----------------------------------------------------------------
# Processing city # 39 | City name = belushya guba.
# -----------------------------------------------------------------
# City belushya guba is not found.
# -----------------------------------------------------------------
# Processing city # 40 | City name = husavik.
# -----------------------------------------------------------------
# Processing city # 41 | City name = henties bay.
# -----------------------------------------------------------------
# Processing city # 42 | City name = port elizabeth.
# -----------------------------------------------------------------
# Processing city # 43 | City name = illoqqortoormiut.
# -----------------------------------------------------------------
# City illoqqortoormiut is not found.
# -----------------------------------------------------------------
# Processing city # 44 | City name = ordzhonikidze.
# -----------------------------------------------------------------
# Processing city # 45 | City name = castro.
# -----------------------------------------------------------------
# Processing city # 46 | City name = shimoda.
# -----------------------------------------------------------------
# Processing city # 47 | City name = vaini.
# -----------------------------------------------------------------
# Processing city # 48 | City name = ushuaia.
# -----------------------------------------------------------------
# Processing city # 49 | City name = atuona.
# -----------------------------------------------------------------
# Processing city # 50 | City name = laguna.
# -----------------------------------------------------------------
# Processing city # 51 | City name = kargasok.
# -----------------------------------------------------------------
# Processing city # 52 | City name = presidencia roque saenz pena.
# -----------------------------------------------------------------
# Processing city # 53 | City name = ancud.
# -----------------------------------------------------------------
# Processing city # 54 | City name = ayr.
# -----------------------------------------------------------------
# Processing city # 55 | City name = louisbourg.
# -----------------------------------------------------------------
# City louisbourg is not found.
# -----------------------------------------------------------------
# Processing city # 56 | City name = qasigiannguit.
# -----------------------------------------------------------------
# Processing city # 57 | City name = qaqortoq.
# -----------------------------------------------------------------
# Processing city # 58 | City name = georgetown.
# -----------------------------------------------------------------
# Processing city # 59 | City name = taolanaro.
# -----------------------------------------------------------------
# City taolanaro is not found.
# -----------------------------------------------------------------
# Processing city # 60 | City name = vagur.
# -----------------------------------------------------------------
# Processing city # 61 | City name = mahebourg.
# -----------------------------------------------------------------
# Processing city # 62 | City name = rundu.
# -----------------------------------------------------------------
# Processing city # 63 | City name = lompoc.
# -----------------------------------------------------------------
# Processing city # 64 | City name = nemuro.
# -----------------------------------------------------------------
# Processing city # 65 | City name = kaitangata.
# -----------------------------------------------------------------
# Processing city # 66 | City name = lebu.
# -----------------------------------------------------------------
# Processing city # 67 | City name = amderma.
# -----------------------------------------------------------------
# City amderma is not found.
# -----------------------------------------------------------------
# Processing city # 68 | City name = faya.
# -----------------------------------------------------------------
# Processing city # 69 | City name = dikson.
# -----------------------------------------------------------------
# Processing city # 70 | City name = college.
# -----------------------------------------------------------------
# Processing city # 71 | City name = sept-iles.
# -----------------------------------------------------------------
# Processing city # 72 | City name = provideniya.
# -----------------------------------------------------------------
# Processing city # 73 | City name = yanam.
# -----------------------------------------------------------------
# Processing city # 74 | City name = hofn.
# -----------------------------------------------------------------
# Processing city # 75 | City name = saleaula.
# -----------------------------------------------------------------
# City saleaula is not found.
# -----------------------------------------------------------------
# Processing city # 76 | City name = jishou.
# -----------------------------------------------------------------
# Processing city # 77 | City name = flinders.
# -----------------------------------------------------------------
# Processing city # 78 | City name = camacha.
# -----------------------------------------------------------------
# Processing city # 79 | City name = acari.
# -----------------------------------------------------------------
# Processing city # 80 | City name = portland.
# -----------------------------------------------------------------
# Processing city # 81 | City name = ribeira grande.
# -----------------------------------------------------------------
# Processing city # 82 | City name = russellville.
# -----------------------------------------------------------------
# Processing city # 83 | City name = bambous virieux.
# -----------------------------------------------------------------
# Processing city # 84 | City name = la paz.
# -----------------------------------------------------------------
# Processing city # 85 | City name = constitucion.
# -----------------------------------------------------------------
# Processing city # 86 | City name = lagoa.
# -----------------------------------------------------------------
# Processing city # 87 | City name = chiredzi.
# -----------------------------------------------------------------
# Processing city # 88 | City name = maraa.
# -----------------------------------------------------------------
# Processing city # 89 | City name = avera.
# -----------------------------------------------------------------
# Processing city # 90 | City name = mago.
# -----------------------------------------------------------------
# Processing city # 91 | City name = porto novo.
# -----------------------------------------------------------------
# Processing city # 92 | City name = nantucket.
# -----------------------------------------------------------------
# Processing city # 93 | City name = neuquen.
# -----------------------------------------------------------------
# Processing city # 94 | City name = werneck.
# -----------------------------------------------------------------
# Processing city # 95 | City name = havoysund.
# -----------------------------------------------------------------
# Processing city # 96 | City name = new norfolk.
# -----------------------------------------------------------------
# Processing city # 97 | City name = laramie.
# -----------------------------------------------------------------
# Processing city # 98 | City name = stilling.
# -----------------------------------------------------------------
# Processing city # 99 | City name = puerto leguizamo.
# -----------------------------------------------------------------
# Processing city # 100 | City name = saint george.
# -----------------------------------------------------------------
# Processing city # 101 | City name = douentza.
# -----------------------------------------------------------------
# Processing city # 102 | City name = thompson.
# -----------------------------------------------------------------
# Processing city # 103 | City name = elliot lake.
# -----------------------------------------------------------------
# Processing city # 104 | City name = san policarpo.
# -----------------------------------------------------------------
# Processing city # 105 | City name = souillac.
# -----------------------------------------------------------------
# Processing city # 106 | City name = eenhana.
# -----------------------------------------------------------------
# Processing city # 107 | City name = mys shmidta.
# -----------------------------------------------------------------
# City mys shmidta is not found.
# -----------------------------------------------------------------
# Processing city # 108 | City name = narrabri.
# -----------------------------------------------------------------
# Processing city # 109 | City name = honiara.
# -----------------------------------------------------------------
# Processing city # 110 | City name = butaritari.
# -----------------------------------------------------------------
# Processing city # 111 | City name = boden.
# -----------------------------------------------------------------
# Processing city # 112 | City name = dakar.
# -----------------------------------------------------------------
# Processing city # 113 | City name = khromtau.
# -----------------------------------------------------------------
# Processing city # 114 | City name = esperance.
# -----------------------------------------------------------------
# Processing city # 115 | City name = avarua.
# -----------------------------------------------------------------
# Processing city # 116 | City name = nizhneyansk.
# -----------------------------------------------------------------
# City nizhneyansk is not found.
# -----------------------------------------------------------------
# Processing city # 117 | City name = jamestown.
# -----------------------------------------------------------------
# Processing city # 118 | City name = melo.
# -----------------------------------------------------------------
# Processing city # 119 | City name = hasaki.
# -----------------------------------------------------------------
# Processing city # 120 | City name = new smyrna beach.
# -----------------------------------------------------------------
# Processing city # 121 | City name = saint-philippe.
# -----------------------------------------------------------------
# Processing city # 122 | City name = kawalu.
# -----------------------------------------------------------------
# Processing city # 123 | City name = san cristobal.
# -----------------------------------------------------------------
# Processing city # 124 | City name = warrington.
# -----------------------------------------------------------------
# Processing city # 125 | City name = sokolo.
# -----------------------------------------------------------------
# Processing city # 126 | City name = codroipo.
# -----------------------------------------------------------------
# Processing city # 127 | City name = khatanga.
# -----------------------------------------------------------------
# Processing city # 128 | City name = port macquarie.
# -----------------------------------------------------------------
# Processing city # 129 | City name = salekhard.
# -----------------------------------------------------------------
# Processing city # 130 | City name = sao felix do xingu.
# -----------------------------------------------------------------
# Processing city # 131 | City name = kamenka.
# -----------------------------------------------------------------
# Processing city # 132 | City name = airai.
# -----------------------------------------------------------------
# Processing city # 133 | City name = cayenne.
# -----------------------------------------------------------------
# Processing city # 134 | City name = puerto carreno.
# -----------------------------------------------------------------
# Processing city # 135 | City name = pevek.
# -----------------------------------------------------------------
# Processing city # 136 | City name = venice.
# -----------------------------------------------------------------
# Processing city # 137 | City name = petropavlovsk-kamchatskiy.
# -----------------------------------------------------------------
# Processing city # 138 | City name = klaksvik.
# -----------------------------------------------------------------
# Processing city # 139 | City name = saskylakh.
# -----------------------------------------------------------------
# Processing city # 140 | City name = redmond.
# -----------------------------------------------------------------
# Processing city # 141 | City name = caravelas.
# -----------------------------------------------------------------
# Processing city # 142 | City name = nouadhibou.
# -----------------------------------------------------------------
# Processing city # 143 | City name = ixtapa.
# -----------------------------------------------------------------
# Processing city # 144 | City name = garmsar.
# -----------------------------------------------------------------
# Processing city # 145 | City name = dingle.
# -----------------------------------------------------------------
# Processing city # 146 | City name = tokur.
# -----------------------------------------------------------------
# Processing city # 147 | City name = vestbygda.
# -----------------------------------------------------------------
# City vestbygda is not found.
# -----------------------------------------------------------------
# Processing city # 148 | City name = londoko.
# -----------------------------------------------------------------
# Processing city # 149 | City name = palmer.
# -----------------------------------------------------------------
# Processing city # 150 | City name = yulara.
# -----------------------------------------------------------------
# Processing city # 151 | City name = yerbogachen.
# -----------------------------------------------------------------
# Processing city # 152 | City name = tual.
# -----------------------------------------------------------------
# Processing city # 153 | City name = talcahuano.
# -----------------------------------------------------------------
# Processing city # 154 | City name = ahipara.
# -----------------------------------------------------------------
# Processing city # 155 | City name = guaymas.
# -----------------------------------------------------------------
# Processing city # 156 | City name = kodiak.
# -----------------------------------------------------------------
# Processing city # 157 | City name = vao.
# -----------------------------------------------------------------
# Processing city # 158 | City name = carauari.
# -----------------------------------------------------------------
# Processing city # 159 | City name = chokurdakh.
# -----------------------------------------------------------------
# Processing city # 160 | City name = canutama.
# -----------------------------------------------------------------
# Processing city # 161 | City name = boa vista.
# -----------------------------------------------------------------
# Processing city # 162 | City name = roald.
# -----------------------------------------------------------------
# Processing city # 163 | City name = aklavik.
# -----------------------------------------------------------------
# Processing city # 164 | City name = saint-pierre.
# -----------------------------------------------------------------
# Processing city # 165 | City name = impfondo.
# -----------------------------------------------------------------
# Processing city # 166 | City name = carballo.
# -----------------------------------------------------------------
# Processing city # 167 | City name = beringovskiy.
# -----------------------------------------------------------------
# Processing city # 168 | City name = asau.
# -----------------------------------------------------------------
# Processing city # 169 | City name = boundiali.
# -----------------------------------------------------------------
# Processing city # 170 | City name = yellowknife.
# -----------------------------------------------------------------
# Processing city # 171 | City name = nikolskoye.
# -----------------------------------------------------------------
# Processing city # 172 | City name = verkhnyaya inta.
# -----------------------------------------------------------------
# Processing city # 173 | City name = cockburn town.
# -----------------------------------------------------------------
# Processing city # 174 | City name = udalguri.
# -----------------------------------------------------------------
# Processing city # 175 | City name = champerico.
# -----------------------------------------------------------------
# Processing city # 176 | City name = tuktoyaktuk.
# -----------------------------------------------------------------
# Processing city # 177 | City name = ponta do sol.
# -----------------------------------------------------------------
# Processing city # 178 | City name = linfen.
# -----------------------------------------------------------------
# Processing city # 179 | City name = azare.
# -----------------------------------------------------------------
# Processing city # 180 | City name = ayan.
# -----------------------------------------------------------------
# Processing city # 181 | City name = port hedland.
# -----------------------------------------------------------------
# Processing city # 182 | City name = bluff.
# -----------------------------------------------------------------
# Processing city # 183 | City name = rawson.
# -----------------------------------------------------------------
# Processing city # 184 | City name = bayangol.
# -----------------------------------------------------------------
# Processing city # 185 | City name = iberia.
# -----------------------------------------------------------------
# Processing city # 186 | City name = camapua.
# -----------------------------------------------------------------
# Processing city # 187 | City name = vila franca do campo.
# -----------------------------------------------------------------
# Processing city # 188 | City name = norman wells.
# -----------------------------------------------------------------
# Processing city # 189 | City name = padampur.
# -----------------------------------------------------------------
# Processing city # 190 | City name = sur.
# -----------------------------------------------------------------
# Processing city # 191 | City name = kudahuvadhoo.
# -----------------------------------------------------------------
# Processing city # 192 | City name = karratha.
# -----------------------------------------------------------------
# Processing city # 193 | City name = dalaba.
# -----------------------------------------------------------------
# Processing city # 194 | City name = valle de allende.
# -----------------------------------------------------------------
# Processing city # 195 | City name = hurghada.
# -----------------------------------------------------------------
# Processing city # 196 | City name = bengkulu.
# -----------------------------------------------------------------
# Processing city # 197 | City name = ibipeba.
# -----------------------------------------------------------------
# Processing city # 198 | City name = hobyo.
# -----------------------------------------------------------------
# Processing city # 199 | City name = east london.
# -----------------------------------------------------------------
# Processing city # 200 | City name = hithadhoo.
# -----------------------------------------------------------------
# Processing city # 201 | City name = tautira.
# -----------------------------------------------------------------
# Processing city # 202 | City name = longyearbyen.
# -----------------------------------------------------------------
# Processing city # 203 | City name = burica.
# -----------------------------------------------------------------
# City burica is not found.
# -----------------------------------------------------------------
# Processing city # 204 | City name = praia da vitoria.
# -----------------------------------------------------------------
# Processing city # 205 | City name = gizo.
# -----------------------------------------------------------------
# Processing city # 206 | City name = ambon.
# -----------------------------------------------------------------
# Processing city # 207 | City name = kapaa.
# -----------------------------------------------------------------
# Processing city # 208 | City name = belmonte.
# -----------------------------------------------------------------
# Processing city # 209 | City name = wangou.
# -----------------------------------------------------------------
# Processing city # 210 | City name = pisco.
# -----------------------------------------------------------------
# Processing city # 211 | City name = evensk.
# -----------------------------------------------------------------
# Processing city # 212 | City name = tazovskiy.
# -----------------------------------------------------------------
# Processing city # 213 | City name = ostrovnoy.
# -----------------------------------------------------------------
# Processing city # 214 | City name = maxixe.
# -----------------------------------------------------------------
# Processing city # 215 | City name = barentsburg.
# -----------------------------------------------------------------
# City barentsburg is not found.
# -----------------------------------------------------------------
# Processing city # 216 | City name = kokoda.
# -----------------------------------------------------------------
# Processing city # 217 | City name = fort nelson.
# -----------------------------------------------------------------
# Processing city # 218 | City name = buckeye.
# -----------------------------------------------------------------
# Processing city # 219 | City name = port alfred.
# -----------------------------------------------------------------
# Processing city # 220 | City name = najran.
# -----------------------------------------------------------------
# Processing city # 221 | City name = kracheh.
# -----------------------------------------------------------------
# City kracheh is not found.
# -----------------------------------------------------------------
# Processing city # 222 | City name = ballina.
# -----------------------------------------------------------------
# Processing city # 223 | City name = jalu.
# -----------------------------------------------------------------
# Processing city # 224 | City name = ilulissat.
# -----------------------------------------------------------------
# Processing city # 225 | City name = torbay.
# -----------------------------------------------------------------
# Processing city # 226 | City name = pokrovsk.
# -----------------------------------------------------------------
# Processing city # 227 | City name = colchester.
# -----------------------------------------------------------------
# Processing city # 228 | City name = faanui.
# -----------------------------------------------------------------
# Processing city # 229 | City name = talnakh.
# -----------------------------------------------------------------
# Processing city # 230 | City name = alexander city.
# -----------------------------------------------------------------
# Processing city # 231 | City name = tilichiki.
# -----------------------------------------------------------------
# Processing city # 232 | City name = porciuncula.
# -----------------------------------------------------------------
# Processing city # 233 | City name = san patricio.
# -----------------------------------------------------------------
# Processing city # 234 | City name = port-gentil.
# -----------------------------------------------------------------
# Processing city # 235 | City name = vaitupu.
# -----------------------------------------------------------------
# City vaitupu is not found.
# -----------------------------------------------------------------
# Processing city # 236 | City name = reefton.
# -----------------------------------------------------------------
# City reefton is not found.
# -----------------------------------------------------------------
# Processing city # 237 | City name = kahului.
# -----------------------------------------------------------------
# Processing city # 238 | City name = buenaventura.
# -----------------------------------------------------------------
# Processing city # 239 | City name = mora.
# -----------------------------------------------------------------
# Processing city # 240 | City name = port hardy.
# -----------------------------------------------------------------
# Processing city # 241 | City name = chumikan.
# -----------------------------------------------------------------
# Processing city # 242 | City name = nizhnyaya tavda.
# -----------------------------------------------------------------
# Processing city # 243 | City name = sitka.
# -----------------------------------------------------------------
# Processing city # 244 | City name = saint anthony.
# -----------------------------------------------------------------
# Processing city # 245 | City name = kavieng.
# -----------------------------------------------------------------
# Processing city # 246 | City name = orcopampa.
# -----------------------------------------------------------------
# Processing city # 247 | City name = marcona.
# -----------------------------------------------------------------
# City marcona is not found.
# -----------------------------------------------------------------
# Processing city # 248 | City name = grindavik.
# -----------------------------------------------------------------
# Processing city # 249 | City name = khandyga.
# -----------------------------------------------------------------
# Processing city # 250 | City name = buqayq.
# -----------------------------------------------------------------
# City buqayq is not found.
# -----------------------------------------------------------------
# Processing city # 251 | City name = charagua.
# -----------------------------------------------------------------
# Processing city # 252 | City name = iralaya.
# -----------------------------------------------------------------
# Processing city # 253 | City name = cururupu.
# -----------------------------------------------------------------
# Processing city # 254 | City name = kamenskoye.
# -----------------------------------------------------------------
# City kamenskoye is not found.
# -----------------------------------------------------------------
# Processing city # 255 | City name = methoni.
# -----------------------------------------------------------------
# Processing city # 256 | City name = phan rang.
# -----------------------------------------------------------------
# City phan rang is not found.
# -----------------------------------------------------------------
# Processing city # 257 | City name = banff.
# -----------------------------------------------------------------
# Processing city # 258 | City name = attawapiskat.
# -----------------------------------------------------------------
# City attawapiskat is not found.
# -----------------------------------------------------------------
# Processing city # 259 | City name = pangody.
# -----------------------------------------------------------------
# Processing city # 260 | City name = comodoro rivadavia.
# -----------------------------------------------------------------
# Processing city # 261 | City name = nelson bay.
# -----------------------------------------------------------------
# Processing city # 262 | City name = bonavista.
# -----------------------------------------------------------------
# Processing city # 263 | City name = corinto.
# -----------------------------------------------------------------
# Processing city # 264 | City name = madang.
# -----------------------------------------------------------------
# Processing city # 265 | City name = gravelbourg.
# -----------------------------------------------------------------
# Processing city # 266 | City name = casino.
# -----------------------------------------------------------------
# Processing city # 267 | City name = hermon.
# -----------------------------------------------------------------
# Processing city # 268 | City name = harer.
# -----------------------------------------------------------------
# Processing city # 269 | City name = leningradskiy.
# -----------------------------------------------------------------
# Processing city # 270 | City name = plettenberg bay.
# -----------------------------------------------------------------
# Processing city # 271 | City name = hamilton.
# -----------------------------------------------------------------
# Processing city # 272 | City name = baracoa.
# -----------------------------------------------------------------
# Processing city # 273 | City name = waddan.
# -----------------------------------------------------------------
# Processing city # 274 | City name = clyde river.
# -----------------------------------------------------------------
# Processing city # 275 | City name = baruun-urt.
# -----------------------------------------------------------------
# Processing city # 276 | City name = helong.
# -----------------------------------------------------------------
# Processing city # 277 | City name = ambovombe.
# -----------------------------------------------------------------
# Processing city # 278 | City name = ereymentau.
# -----------------------------------------------------------------
# Processing city # 279 | City name = tasiilaq.
# -----------------------------------------------------------------
# Processing city # 280 | City name = puerto madryn.
# -----------------------------------------------------------------
# Processing city # 281 | City name = aleksandrovsk-sakhalinskiy.
# -----------------------------------------------------------------
# Processing city # 282 | City name = sarkand.
# -----------------------------------------------------------------
# Processing city # 283 | City name = sakakah.
# -----------------------------------------------------------------
# Processing city # 284 | City name = beira.
# -----------------------------------------------------------------
# Processing city # 285 | City name = cape coast.
# -----------------------------------------------------------------
# Processing city # 286 | City name = bathsheba.
# -----------------------------------------------------------------
# Processing city # 287 | City name = tura.
# -----------------------------------------------------------------
# Processing city # 288 | City name = rakaia.
# -----------------------------------------------------------------
# Processing city # 289 | City name = geraldton.
# -----------------------------------------------------------------
# Processing city # 290 | City name = dunedin.
# -----------------------------------------------------------------
# Processing city # 291 | City name = assomada.
# -----------------------------------------------------------------
# Processing city # 292 | City name = george.
# -----------------------------------------------------------------
# Processing city # 293 | City name = lakhdenpokhya.
# -----------------------------------------------------------------
# Processing city # 294 | City name = kaabong.
# -----------------------------------------------------------------
# Processing city # 295 | City name = madingou.
# -----------------------------------------------------------------
# Processing city # 296 | City name = taber.
# -----------------------------------------------------------------
# Processing city # 297 | City name = westport.
# -----------------------------------------------------------------
# Processing city # 298 | City name = sumbe.
# -----------------------------------------------------------------
# Processing city # 299 | City name = abu samrah.
# -----------------------------------------------------------------
# Processing city # 300 | City name = weihai.
# -----------------------------------------------------------------
# Processing city # 301 | City name = monster.
# -----------------------------------------------------------------
# Processing city # 302 | City name = masuguru.
# -----------------------------------------------------------------
# Processing city # 303 | City name = mahon.
# -----------------------------------------------------------------
# Processing city # 304 | City name = bethel.
# -----------------------------------------------------------------
# Processing city # 305 | City name = beloha.
# -----------------------------------------------------------------
# Processing city # 306 | City name = upernavik.
# -----------------------------------------------------------------
# Processing city # 307 | City name = chapais.
# -----------------------------------------------------------------
# Processing city # 308 | City name = flin flon.
# -----------------------------------------------------------------
# Processing city # 309 | City name = mandan.
# -----------------------------------------------------------------
# Processing city # 310 | City name = brownsville.
# -----------------------------------------------------------------
# Processing city # 311 | City name = california city.
# -----------------------------------------------------------------
# Processing city # 312 | City name = wuwei.
# -----------------------------------------------------------------
# Processing city # 313 | City name = syamzha.
# -----------------------------------------------------------------
# Processing city # 314 | City name = vestmanna.
# -----------------------------------------------------------------
# Processing city # 315 | City name = rosarito.
# -----------------------------------------------------------------
# Processing city # 316 | City name = chinsali.
# -----------------------------------------------------------------
# Processing city # 317 | City name = beyneu.
# -----------------------------------------------------------------
# Processing city # 318 | City name = moose factory.
# -----------------------------------------------------------------
# Processing city # 319 | City name = salalah.
# -----------------------------------------------------------------
# Processing city # 320 | City name = guerrero negro.
# -----------------------------------------------------------------
# Processing city # 321 | City name = karaul.
# -----------------------------------------------------------------
# City karaul is not found.
# -----------------------------------------------------------------
# Processing city # 322 | City name = kotka.
# -----------------------------------------------------------------
# Processing city # 323 | City name = velyka lepetykha.
# -----------------------------------------------------------------
# Processing city # 324 | City name = richards bay.
# -----------------------------------------------------------------
# Processing city # 325 | City name = xai-xai.
# -----------------------------------------------------------------
# Processing city # 326 | City name = umm lajj.
# -----------------------------------------------------------------
# Processing city # 327 | City name = kyabe.
# -----------------------------------------------------------------
# Processing city # 328 | City name = teguldet.
# -----------------------------------------------------------------
# Processing city # 329 | City name = novochernorechenskiy.
# -----------------------------------------------------------------
# Processing city # 330 | City name = hambantota.
# -----------------------------------------------------------------
# Processing city # 331 | City name = nanortalik.
# -----------------------------------------------------------------
# Processing city # 332 | City name = agra.
# -----------------------------------------------------------------
# Processing city # 333 | City name = katobu.
# -----------------------------------------------------------------
# Processing city # 334 | City name = brae.
# -----------------------------------------------------------------
# Processing city # 335 | City name = makakilo city.
# -----------------------------------------------------------------
# Processing city # 336 | City name = ust-nera.
# -----------------------------------------------------------------
# Processing city # 337 | City name = lesogorskiy.
# -----------------------------------------------------------------
# Processing city # 338 | City name = sorland.
# -----------------------------------------------------------------
# Processing city # 339 | City name = marzuq.
# -----------------------------------------------------------------
# Processing city # 340 | City name = pitimbu.
# -----------------------------------------------------------------
# Processing city # 341 | City name = teknaf.
# -----------------------------------------------------------------
# Processing city # 342 | City name = vuktyl.
# -----------------------------------------------------------------
# Processing city # 343 | City name = acapulco.
# -----------------------------------------------------------------
# Processing city # 344 | City name = atherton.
# -----------------------------------------------------------------
# Processing city # 345 | City name = talwara.
# -----------------------------------------------------------------
# Processing city # 346 | City name = grand gaube.
# -----------------------------------------------------------------
# Processing city # 347 | City name = cabo san lucas.
# -----------------------------------------------------------------
# Processing city # 348 | City name = mount isa.
# -----------------------------------------------------------------
# Processing city # 349 | City name = sentyabrskiy.
# -----------------------------------------------------------------
# City sentyabrskiy is not found.
# -----------------------------------------------------------------
# Processing city # 350 | City name = lima.
# -----------------------------------------------------------------
# Processing city # 351 | City name = anadyr.
# -----------------------------------------------------------------
# Processing city # 352 | City name = iskateley.
# -----------------------------------------------------------------
# Processing city # 353 | City name = muncar.
# -----------------------------------------------------------------
# Processing city # 354 | City name = tiznit.
# -----------------------------------------------------------------
# Processing city # 355 | City name = boralday.
# -----------------------------------------------------------------
# Processing city # 356 | City name = saldanha.
# -----------------------------------------------------------------
# Processing city # 357 | City name = damietta.
# -----------------------------------------------------------------
# Processing city # 358 | City name = chlum u trebone.
# -----------------------------------------------------------------
# Processing city # 359 | City name = sorvag.
# -----------------------------------------------------------------
# City sorvag is not found.
# -----------------------------------------------------------------
# Processing city # 360 | City name = goundam.
# -----------------------------------------------------------------
# Processing city # 361 | City name = salamiyah.
# -----------------------------------------------------------------
# Processing city # 362 | City name = bandarbeyla.
# -----------------------------------------------------------------
# Processing city # 363 | City name = igrim.
# -----------------------------------------------------------------
# Processing city # 364 | City name = srednekolymsk.
# -----------------------------------------------------------------
# Processing city # 365 | City name = brenham.
# -----------------------------------------------------------------
# Processing city # 366 | City name = amuntai.
# -----------------------------------------------------------------
# Processing city # 367 | City name = samalaeulu.
# -----------------------------------------------------------------
# City samalaeulu is not found.
# -----------------------------------------------------------------
# Processing city # 368 | City name = namibe.
# -----------------------------------------------------------------
# Processing city # 369 | City name = falmouth.
# -----------------------------------------------------------------
# Processing city # 370 | City name = pamanukan.
# -----------------------------------------------------------------
# Processing city # 371 | City name = berlevag.
# -----------------------------------------------------------------
# Processing city # 372 | City name = portlethen.
# -----------------------------------------------------------------
# Processing city # 373 | City name = pontian kecil.
# -----------------------------------------------------------------
# Processing city # 374 | City name = hovd.
# -----------------------------------------------------------------
# Processing city # 375 | City name = padang.
# -----------------------------------------------------------------
# Processing city # 376 | City name = pacifica.
# -----------------------------------------------------------------
# Processing city # 377 | City name = carutapera.
# -----------------------------------------------------------------
# Processing city # 378 | City name = ipixuna.
# -----------------------------------------------------------------
# Processing city # 379 | City name = lisakovsk.
# -----------------------------------------------------------------
# Processing city # 380 | City name = tshela.
# -----------------------------------------------------------------
# Processing city # 381 | City name = itarema.
# -----------------------------------------------------------------
# Processing city # 382 | City name = moses lake.
# -----------------------------------------------------------------
# Processing city # 383 | City name = samarai.
# -----------------------------------------------------------------
# Processing city # 384 | City name = ruatoria.
# -----------------------------------------------------------------
# City ruatoria is not found.
# -----------------------------------------------------------------
# Processing city # 385 | City name = santa ana.
# -----------------------------------------------------------------
# Processing city # 386 | City name = linxia.
# -----------------------------------------------------------------
# Processing city # 387 | City name = tashla.
# -----------------------------------------------------------------
# Processing city # 388 | City name = zhigansk.
# -----------------------------------------------------------------
# Processing city # 389 | City name = malwan.
# -----------------------------------------------------------------
# City malwan is not found.
# -----------------------------------------------------------------
# Processing city # 390 | City name = pacific grove.
# -----------------------------------------------------------------
# Processing city # 391 | City name = westerland.
# -----------------------------------------------------------------
# Processing city # 392 | City name = wanning.
# -----------------------------------------------------------------
# Processing city # 393 | City name = surt.
# -----------------------------------------------------------------
# Processing city # 394 | City name = lahad datu.
# -----------------------------------------------------------------
# Processing city # 395 | City name = gasa.
# -----------------------------------------------------------------
# Processing city # 396 | City name = kedrovyy.
# -----------------------------------------------------------------
# Processing city # 397 | City name = stornoway.
# -----------------------------------------------------------------
# Processing city # 398 | City name = casper.
# -----------------------------------------------------------------
# Processing city # 399 | City name = zeya.
# -----------------------------------------------------------------
# Processing city # 400 | City name = sangmelima.
# -----------------------------------------------------------------
# Processing city # 401 | City name = manicaragua.
# -----------------------------------------------------------------
# Processing city # 402 | City name = mehamn.
# -----------------------------------------------------------------
# Processing city # 403 | City name = toliary.
# -----------------------------------------------------------------
# City toliary is not found.
# -----------------------------------------------------------------
# Processing city # 404 | City name = novobirilyussy.
# -----------------------------------------------------------------
# Processing city # 405 | City name = mana.
# ...
# -----------------------------------------------------------------
# Processing city # 450 | City name = ust-ilimsk.
# -----------------------------------------------------------------
# Processing city # 451 | City name = busayra.
# -----------------------------------------------------------------
# Processing city # 452 | City name = san quintin.
# -----------------------------------------------------------------
# Processing city # 453 | City name = abu dhabi.
# -----------------------------------------------------------------
# Processing city # 454 | City name = tsabong.
# -----------------------------------------------------------------
# Processing city # 455 | City name = khakhea.
# -----------------------------------------------------------------
# Processing city # 456 | City name = nadadores.
# -----------------------------------------------------------------
# Processing city # 457 | City name = shingu.
# -----------------------------------------------------------------
# Processing city # 458 | City name = marawi.
# -----------------------------------------------------------------
# Processing city # 459 | City name = eyl.
# -----------------------------------------------------------------
# Processing city # 460 | City name = codrington.
# -----------------------------------------------------------------
# Processing city # 461 | City name = magadan.
# -----------------------------------------------------------------
# Processing city # 462 | City name = nova olimpia.
# -----------------------------------------------------------------
# Processing city # 463 | City name = camana.
# -----------------------------------------------------------------
# Processing city # 464 | City name = mullaitivu.
# -----------------------------------------------------------------
# City mullaitivu is not found.
# -----------------------------------------------------------------
# Processing city # 465 | City name = puerto colombia.
# -----------------------------------------------------------------
# Processing city # 466 | City name = canakkale.
# -----------------------------------------------------------------
# Processing city # 467 | City name = berezayka.
# -----------------------------------------------------------------
# Processing city # 468 | City name = opuwo.
# -----------------------------------------------------------------
# Processing city # 469 | City name = mongoumba.
# -----------------------------------------------------------------
# Processing city # 470 | City name = jizan.
# -----------------------------------------------------------------
# Processing city # 471 | City name = fuerte olimpo.
# -----------------------------------------------------------------
# Processing city # 472 | City name = bababe.
# -----------------------------------------------------------------
# City bababe is not found.
# -----------------------------------------------------------------
# Processing city # 473 | City name = santa isabel do rio negro.
# -----------------------------------------------------------------
# Processing city # 474 | City name = barbastro.
# -----------------------------------------------------------------
# Processing city # 475 | City name = nara.
# -----------------------------------------------------------------
# Processing city # 476 | City name = tome.
# -----------------------------------------------------------------
# Processing city # 477 | City name = lawrenceville.
# -----------------------------------------------------------------
# Processing city # 478 | City name = prince rupert.
# -----------------------------------------------------------------
# Processing city # 479 | City name = paris.
# -----------------------------------------------------------------
# Processing city # 480 | City name = adrar.
# -----------------------------------------------------------------
# Processing city # 481 | City name = trairi.
# -----------------------------------------------------------------
# Processing city # 482 | City name = kavaratti.
# -----------------------------------------------------------------
# Processing city # 483 | City name = nawa.
# -----------------------------------------------------------------
# Processing city # 484 | City name = betlitsa.
# -----------------------------------------------------------------
# Processing city # 485 | City name = malyye derbety.
# -----------------------------------------------------------------
# Processing city # 486 | City name = exeter.
# -----------------------------------------------------------------
# Processing city # 487 | City name = olafsvik.
# -----------------------------------------------------------------
# Processing city # 488 | City name = hokitika.
# -----------------------------------------------------------------
# Processing city # 489 | City name = inhambane.
# -----------------------------------------------------------------
# Processing city # 490 | City name = seybaplaya.
# -----------------------------------------------------------------
# Processing city # 491 | City name = kautokeino.
# -----------------------------------------------------------------
# Processing city # 492 | City name = deputatskiy.
# -----------------------------------------------------------------
# Processing city # 493 | City name = dergachi.
# -----------------------------------------------------------------
# Processing city # 494 | City name = los llanos de aridane.
# -----------------------------------------------------------------
# Processing city # 495 | City name = mogadishu.
# -----------------------------------------------------------------
# Processing city # 496 | City name = turbat.
# -----------------------------------------------------------------
# Processing city # 497 | City name = aflu.
# -----------------------------------------------------------------
# City aflu is not found.
# -----------------------------------------------------------------
# Processing city # 498 | City name = kenitra.
# -----------------------------------------------------------------
# Processing city # 499 | City name = palmeirais.
# -----------------------------------------------------------------
# Processing city # 500 | City name = cubara.
# -----------------------------------------------------------------
# Processing city # 501 | City name = port lincoln.
# -----------------------------------------------------------------
# Processing city # 502 | City name = alofi.
# -----------------------------------------------------------------
# Processing city # 503 | City name = menongue.
# -----------------------------------------------------------------
# Processing city # 504 | City name = kafanchan.
# -----------------------------------------------------------------
# Processing city # 505 | City name = lyaskelya.
# -----------------------------------------------------------------
# Processing city # 506 | City name = jinchang.
# -----------------------------------------------------------------
# Processing city # 507 | City name = goianesia.
# -----------------------------------------------------------------
# Processing city # 508 | City name = crab hill.
# -----------------------------------------------------------------
# City crab hill is not found.
# -----------------------------------------------------------------
# Processing city # 509 | City name = gunupur.
# -----------------------------------------------------------------
# Processing city # 510 | City name = burnie.
# -----------------------------------------------------------------
# Processing city # 511 | City name = turukhansk.
# -----------------------------------------------------------------
# Processing city # 512 | City name = krasnoborsk.
# -----------------------------------------------------------------
# Processing city # 513 | City name = lahij.
# -----------------------------------------------------------------
# Processing city # 514 | City name = asuncion.
# -----------------------------------------------------------------
# Processing city # 515 | City name = abnub.
# -----------------------------------------------------------------
# Processing city # 516 | City name = necochea.
# -----------------------------------------------------------------
# Processing city # 517 | City name = yuci.
# -----------------------------------------------------------------
# Processing city # 518 | City name = liverpool.
# -----------------------------------------------------------------
# Processing city # 519 | City name = lorengau.
# -----------------------------------------------------------------
# Processing city # 520 | City name = hami.
# -----------------------------------------------------------------
# Processing city # 521 | City name = manokwari.
# -----------------------------------------------------------------
# Processing city # 522 | City name = lakes entrance.
# -----------------------------------------------------------------
# Processing city # 523 | City name = tula.
# -----------------------------------------------------------------
# Processing city # 524 | City name = uyskoye.
# -----------------------------------------------------------------
# Processing city # 525 | City name = zvishavane.
# -----------------------------------------------------------------
# Processing city # 526 | City name = bubaque.
# -----------------------------------------------------------------
# Processing city # 527 | City name = lithgow.
# -----------------------------------------------------------------
# Processing city # 528 | City name = qeshm.
# -----------------------------------------------------------------
# Processing city # 529 | City name = granger.
# -----------------------------------------------------------------
# Processing city # 530 | City name = te anau.
# -----------------------------------------------------------------
# Processing city # 531 | City name = santa rosa.
# -----------------------------------------------------------------
# Processing city # 532 | City name = huarmey.
# -----------------------------------------------------------------
# Processing city # 533 | City name = skibbereen.
# -----------------------------------------------------------------
# Processing city # 534 | City name = olden.
# -----------------------------------------------------------------
# Processing city # 535 | City name = fairbanks.
# -----------------------------------------------------------------
# Processing city # 536 | City name = nueva italia de ruiz.
# -----------------------------------------------------------------
# Processing city # 537 | City name = tumannyy.
# -----------------------------------------------------------------
# City tumannyy is not found.
# -----------------------------------------------------------------
# Processing city # 538 | City name = uroteppa.
# -----------------------------------------------------------------
# City uroteppa is not found.
# -----------------------------------------------------------------
# Processing city # 539 | City name = chara.
# -----------------------------------------------------------------
# Processing city # 540 | City name = ji-parana.
# -----------------------------------------------------------------
# City ji-parana is not found.
# -----------------------------------------------------------------
# Processing city # 541 | City name = lazurne.
# -----------------------------------------------------------------
# Processing city # 542 | City name = yangjiang.
# -----------------------------------------------------------------
# Processing city # 543 | City name = idil.
# -----------------------------------------------------------------
# Processing city # 544 | City name = kodar.
# -----------------------------------------------------------------
# Processing city # 545 | City name = dickinson.
# -----------------------------------------------------------------
# Processing city # 546 | City name = zavodouspenskoye.
# -----------------------------------------------------------------
# Processing city # 547 | City name = durango.
# -----------------------------------------------------------------
# Processing city # 548 | City name = la palma.
# -----------------------------------------------------------------
# Processing city # 549 | City name = sabinov.
# -----------------------------------------------------------------
# Processing city # 550 | City name = verkhnevilyuysk.
# -----------------------------------------------------------------
# Processing city # 551 | City name = ijsselstein.
# -----------------------------------------------------------------
# Processing city # 552 | City name = nuevitas.
# -----------------------------------------------------------------
# Processing city # 553 | City name = sinnamary.
# -----------------------------------------------------------------
# Processing city # 554 | City name = lata.
# -----------------------------------------------------------------
# Processing city # 555 | City name = monze.
# -----------------------------------------------------------------
# Processing city # 556 | City name = aketi.
# -----------------------------------------------------------------
# Processing city # 557 | City name = kuryk.
# -----------------------------------------------------------------
# Processing city # 558 | City name = luderitz.
# -----------------------------------------------------------------
# Processing city # 559 | City name = oyo.
# -----------------------------------------------------------------
# Processing city # 560 | City name = mount gambier.
# -----------------------------------------------------------------
# Processing city # 561 | City name = shaoguan.
# -----------------------------------------------------------------
# Processing city # 562 | City name = shakiso.
# -----------------------------------------------------------------
# Processing city # 563 | City name = vila velha.
# -----------------------------------------------------------------
# Processing city # 564 | City name = picota.
# -----------------------------------------------------------------
# Processing city # 565 | City name = high level.
# -----------------------------------------------------------------
# Processing city # 566 | City name = tyrma.
# -----------------------------------------------------------------
# Processing city # 567 | City name = jiazi.
# -----------------------------------------------------------------
# Processing city # 568 | City name = chickasha.
# -----------------------------------------------------------------
# Processing city # 569 | City name = el alto.
# -----------------------------------------------------------------
# Processing city # 570 | City name = san pedro de ycuamandiyu.
# -----------------------------------------------------------------
# Processing city # 571 | City name = terrace.
# -----------------------------------------------------------------
# Processing city # 572 | City name = aqtobe.
# -----------------------------------------------------------------
# Processing city # 573 | City name = ritchie.
# -----------------------------------------------------------------
# Processing city # 574 | City name = lomovka.
# -----------------------------------------------------------------
# Processing city # 575 | City name = tiebissou.
# -----------------------------------------------------------------
# Processing city # 576 | City name = warqla.
# -----------------------------------------------------------------
# City warqla is not found.
# -----------------------------------------------------------------
# Processing city # 577 | City name = sooke.
# -----------------------------------------------------------------
# Processing city # 578 | City name = nueva helvecia.
# -----------------------------------------------------------------
# Processing city # 579 | City name = egvekinot.
# -----------------------------------------------------------------
# Processing city # 580 | City name = tsihombe.
# -----------------------------------------------------------------
# City tsihombe is not found.
# -----------------------------------------------------------------
# Processing city # 581 | City name = andros town.
# -----------------------------------------------------------------
# Processing city # 582 | City name = hurricane.
# -----------------------------------------------------------------
# Processing city # 583 | City name = sawakin.
# -----------------------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create dataframe from dictionary
city_info_df = pd.DataFrame(all_cities_data)
#city_info_df.head()
# Out:
#        City      Lat      Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  cidreira -30.1811  -50.2056    281.59        56           4        8.15
# 1  hermanus -34.4187   19.2345    284.21        68          99        5.96
# 2   rikitea -23.1203 -134.9692    296.50        78         100        6.83
# 3    harper   4.3750   -7.7169    297.85        74         100        3.37
# 4  oksfjord  70.2396   22.3479    284.26        89          28        2.02
#
#   Country        Date
# 0      BR  1627438622
# 1      ZA  1627438623
# 2      PF  1627438625
# 3      LR  1627438626
# 4      NO  1627438628

# %%
city_info_df.to_csv("API_Weather_Data.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_GT_100 = city_info_df.loc[city_info_df['Humidity']>100]

# %%
#  Get the indices of cities that have humidity over 100%.
indices = city_info_df.loc[city_info_df['Humidity']>100]
#indices
# Out:
# Empty DataFrame
# Columns: [City, Lat, Long, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_plot = city_info_df['Lat']
temp_plot = city_info_df['Max Temp']
plt.scatter(lat_plot, temp_plot)
plt.xlabel("Latitude Coordinates")
plt.ylabel("Max Temperature (K)")
plt.title("Latitude vs. Max Temperature")
plt.savefig('latitude_temperature_scatter.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_plot = city_info_df['Lat']
humidity_plot = city_info_df['Humidity']
plt.scatter(lat_plot,humidity_plot)
plt.xlabel("Latitude Coordinates")
plt.ylabel("Humidity (%)")
plt.title("Latitude vs. Humidity")
plt.savefig('latitude_humidity_scatter.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_plot = city_info_df['Lat']
cloudiness_plot = city_info_df['Cloudiness']
plt.scatter(lat_plot,cloudiness_plot)
plt.xlabel("Latitude Coordinates")
plt.ylabel("Cloudiness (%)")
plt.title("Latitude vs. Humidity")
plt.savefig('latitude_cloudiness_scatter.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_plot = city_info_df['Lat']
wind_speed_plot = city_info_df['Wind Speed']
plt.scatter(lat_plot, wind_speed_plot)
plt.xlabel("Latitude Coordinates")
plt.ylabel("Wind Speed (mph)")
plt.title("Latitude vs. Humidity")
plt.savefig('latitude_windspeed_scatter.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Northern hemisphere
northern_hempisphere_df = city_info_df.loc[city_info_df['Lat'] > 0]
northern_hempisphere_df.head()
# Out:
#              City      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 3          harper   4.3750   -7.7169    297.85        74         100
# 4        oksfjord  70.2396   22.3479    284.26        89          28
# 5         margate  51.3813    1.3862    290.95        87          99
# 6      barvinkove  48.9097   37.0205    292.09        63           0
# 7  severo-kurilsk  50.6789  156.1250    288.06        91         100
#
#    Wind Speed Country        Date
# 3        3.37      LR  1627438626
# 4        2.02      NO  1627438628
# 5        1.34      GB  1627438629
# 6        2.00      UA  1627438631
# 7        3.19      RU  1627438632

# %%
#Southern hemisphere
southern_hempisphere_df = city_info_df.loc[city_info_df['Lat'] < 0]
southern_hempisphere_df.head()
# Out:
#               City      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 0         cidreira -30.1811  -50.2056    281.59        56           4
# 1         hermanus -34.4187   19.2345    284.21        68          99
# 2          rikitea -23.1203 -134.9692    296.50        78         100
# 8  arraial do cabo -22.9661  -42.0278    294.60        83           0
# 9        cape town -33.9258   18.4232    284.38        88          20
#
#    Wind Speed Country        Date
# 0        8.15      BR  1627438622
# 1        5.96      ZA  1627438623
# 2        6.83      PF  1627438625
# 8       10.01      BR  1627438633
# 9        0.45      ZA  1627438635

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hempisphere_df['Lat']
y_values = northern_hempisphere_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Northern Hemisphere Latitudes")
plt.ylabel("Max_Temperature (K)")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.savefig('NH_latitude_temperature_regression.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hempisphere_df['Lat']
y_values = southern_hempisphere_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Southern Hemisphere Latitudes")
plt.ylabel("Max_Temperature (K)")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.savefig('SH_latitude_temperature_regression.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hempisphere_df['Lat']
y_values = northern_hempisphere_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Northern Hemisphere Latitudes")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.savefig('NH_latitude_humidity_regression.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hempisphere_df['Lat']
y_values = southern_hempisphere_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Southern Hemisphere Latitudes")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.savefig('SH_latitude_humidity_regression.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hempisphere_df['Lat']
y_values = northern_hempisphere_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Northern Hemisphere Latitudes")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.savefig('NH_latitude_cloudiness_regression.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hempisphere_df['Lat']
y_values = southern_hempisphere_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Southern Hemisphere Latitudes")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.savefig('SH_latitude_cloudiness_regression.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hempisphere_df['Lat']
y_values = northern_hempisphere_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Northern Hemisphere Latitudes")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.savefig('NH_latitude_windspeed_regression.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hempisphere_df['Lat']
y_values = southern_hempisphere_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Southern Hemisphere Latitudes")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.savefig('SH_latitude_windspeed_regression.png', bbox_inches='tight')
plt.show()
