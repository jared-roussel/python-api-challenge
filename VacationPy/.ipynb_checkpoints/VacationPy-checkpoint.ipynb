# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import sys
from pprint import pprint
import time
#jupyter nbextension enable --py gmaps was enabled in git bash
from vacation_config import google_maps_api
gmaps.configure(api_key=google_maps_api)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#API_Weather_Data.csv
file = '../WeatherPy/API_Weather_Data.csv'
api_weather_df = pd.read_csv(file, encoding="ISO-8859-1")
api_weather_df.head()
# Out:
#    Unnamed: 0      City      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 0           0  cidreira -30.1811  -50.2056    281.15        59           4
# 1           1  hermanus -34.4187   19.2345    284.21        66          99
# 2           2   rikitea -23.1203 -134.9692    296.60        79         100
# 3           3    harper   4.3750   -7.7169    297.69        75         100
# 4           4  oksfjord  70.2396   22.3479    284.26        87          25
#
#    Wind Speed Country        Date  Max Temp (F)
# 0        7.96      BR  1627441397        46.400
# 1        5.46      ZA  1627441399        51.908
# 2        6.84      PF  1627441318        74.210
# 3        3.32      LR  1627441401        76.172
# 4        2.14      NO  1627441402        51.998

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations = api_weather_df[['Lat','Long']]
#print(locations)
humidity = api_weather_df['Humidity']
#print(humidity)

# %%
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=1)
# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
wind_speed_df = api_weather_df.loc[api_weather_df['Wind Speed'] < 10]
#wind_speed_df.head()

temp_df_GT_70 = wind_speed_df.loc[wind_speed_df['Max Temp (F)'] > 70]
#temp_df_GT_70.head()

temp_df_LT_80 = temp_df_GT_70.loc[temp_df_GT_70['Max Temp (F)'] < 80]
#temp_df_LT_80.head()

cloudiness_df = temp_df_LT_80.loc[temp_df_LT_80['Cloudiness'] == 0]
#cloudiness_df.head()

final_filtered_df = cloudiness_df.loc[cloudiness_df['Humidity'] < 70]
final_filtered_df
# Out:
#      Unnamed: 0                City      Lat      Long  Max Temp  Humidity  \
# 18           18             grenada  37.1882   -3.6067    295.32        59
# 32           32                khoy  38.5504   44.9535    295.71        54
# 122         122  sao felix do xingu  -6.6447  -51.9950    295.05        50
# 211         211                jalu  29.0331   21.5482    299.49        44
# 254         254              waddan  29.1614   16.1390    296.84        58
# 263         263             sarkand  45.4100   79.9186    296.21        38
# 280         280          abu samrah  35.3029   37.1841    297.93        48
# 303         303    velyka lepetykha  47.1757   33.9436    296.06        67
# 339         339           salamiyah  35.0113   37.0532    296.71        59
# 351         351                hovd  48.0056   91.6419    296.99        30
# 368         368                surt  31.2089   16.5887    298.66        65
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_name_list = []

places_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
radius = 5000
query_type = "lodging"

for i,row in final_filtered_df.iterrows():
    lat = row["Lat"]
    long = row["Long"]
    query_url = f'{places_url}location={lat},{long}&radius={radius}&type={query_type}&key={api_key}'
    
    try:
        response = requests.get(query_url).json()
        hotel_name = response['results'][0]['name']
        hotel_name_list.append(hotel_name)
        
    
    except:
        print(f'{sys.exc_info()[0]}')
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=37.1882,-3.6067&radius=5000&type=lodging&key=AIzaSyBgzZ_6FFoW6kCN_s-9OFyL1nJvtnDj_RQ
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.5504,44.9535&radius=5000&type=lodging&key=AIzaSyBgzZ_6FFoW6kCN_s-9OFyL1nJvtnDj_RQ
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-6.6447,-51.995&radius=5000&type=lodging&key=AIzaSyBgzZ_6FFoW6kCN_s-9OFyL1nJvtnDj_RQ
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=29.0331,21.5482&radius=5000&type=lodging&key=AIzaSyBgzZ_6FFoW6kCN_s-9OFyL1nJvtnDj_RQ
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=29.1614,16.139&radius=5000&type=lodging&key=AIzaSyBgzZ_6FFoW6kCN_s-9OFyL1nJvtnDj_RQ
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=45.41,79.9186&radius=5000&type=lodging&key=AIzaSyBgzZ_6FFoW6kCN_s-9OFyL1nJvtnDj_RQ
# ...

# %%
hotel_name_list = ['HOTEL REINA CRISTINA', 'ترک سل', 'Rio Xingu Camping', 'صاحبة الفخامة', 'محل الشريف محمد العايب', 'Гостиница Сарканд', 'Hotelʹ', 'Missing hotel name', 'Gondolas Forum grandchildren and grandparents', 'Hotel Khovd', 'الهادي ابوشعاله سرت', 'MS Fuente Las Piedras', 'Gostinitsa "Diyar"', 'Romany Adly Gad', 'Thank Inn Plus Hotel Shanxi Jinzhong Yuci District Yingbin West Street Yinhaixinyue']
final_filtered_df.insert(11,"Hotel Name", hotel_name_list)
#final_filtered_df
# Out:
#      Unnamed: 0                City      Lat      Long  Max Temp  Humidity  \
# 18           18             grenada  37.1882   -3.6067    295.32        59
# 32           32                khoy  38.5504   44.9535    295.71        54
# 122         122  sao felix do xingu  -6.6447  -51.9950    295.05        50
# 211         211                jalu  29.0331   21.5482    299.49        44
# 254         254              waddan  29.1614   16.1390    296.84        58
# 263         263             sarkand  45.4100   79.9186    296.21        38
# 280         280          abu samrah  35.3029   37.1841    297.93        48
# 303         303    velyka lepetykha  47.1757   33.9436    296.06        67
# 339         339           salamiyah  35.0113   37.0532    296.71        59
# 351         351                hovd  48.0056   91.6419    296.99        30
# 368         368                surt  31.2089   16.5887    298.66        65
# ...

# %%
hotel_df = final_filtered_df
#hotel_df
# Out:
#      Unnamed: 0                City      Lat      Long  Max Temp  Humidity  \
# 18           18             grenada  37.1882   -3.6067    295.32        59
# 32           32                khoy  38.5504   44.9535    295.71        54
# 122         122  sao felix do xingu  -6.6447  -51.9950    295.05        50
# 211         211                jalu  29.0331   21.5482    299.49        44
# 254         254              waddan  29.1614   16.1390    296.84        58
# 263         263             sarkand  45.4100   79.9186    296.21        38
# 280         280          abu samrah  35.3029   37.1841    297.93        48
# 303         303    velyka lepetykha  47.1757   33.9436    296.06        67
# 339         339           salamiyah  35.0113   37.0532    296.71        59
# 351         351                hovd  48.0056   91.6419    296.99        30
# 368         368                surt  31.2089   16.5887    298.66        65
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Long"]]

# %%
weights = hotel_df['Humidity']
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=weights, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add marker layer on top of heat map
point_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=5,
    info_box_content = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
)


fig = gmaps.figure()
fig.add_layer(point_layer)
fig.add_layer(heat_layer)

fig

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
